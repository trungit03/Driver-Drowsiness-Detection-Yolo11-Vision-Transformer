# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
rm -rf /kaggle/working/*

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.9 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.3 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
# ...

# %%
# !pip install -U albumentations
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 367.1/367.1 kB 9.3 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: albucore
#     Found existing installation: albucore 0.0.23
#     Uninstalling albucore-0.0.23:
#       Successfully uninstalled albucore-0.0.23
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 2.0.4
#     Uninstalling albumentations-2.0.4:
#       Successfully uninstalled albumentations-2.0.4
# ...

# %%
import ultralytics
ultralytics.settings.update({'datasets_dir': '/kaggle/input/drowsy-final/final1'})
print(ultralytics.settings)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/kaggle/input/drowsy-final/final1",
#   "weights_dir": "weights",
#   "runs_dir": "runs",
#   "uuid": "1bfc3e992d24318da58ddee183be5bf9388a31f26bab1738e986ec4d297417ff",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": false,
#   "wandb": false,
#   "vscode_msg": true,
#   "openvino_msg": true
# }

# %%
import torch
print("Số GPU khả dụng:", torch.cuda.device_count())
# Out:
# Số GPU khả dụng: 2

# %%
from ultralytics import YOLO
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt

# %%
model = YOLO('yolov8s.pt')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 194MB/s]

# %%
# !ls /kaggle/input/drowsy-final/final1/data.yaml
# Out:
# /kaggle/input/drowsy-ver5-test-roboflow/data.yaml

# %%
result = model.train(data='/kaggle/input/drowsy-final/final1/data.yaml',
                    batch=64,
                    imgsz=640,
                    epochs=100,
                    optimizer='AdamW',
                    lr0=0.001,
                    close_mosaic=20,
                    pretrained=True,
                     device='0,1')
# Out:
# Ultralytics 8.3.144 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#                                                         CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo val model=/kaggle/working/runs/detect/train/weights/best.pt data=/kaggle/input/drowsy-2-edit-ver3-roboflow/data.yaml

# %%
# !zip -r drowsy-v8s-final.zip /kaggle/working/runs/detect/train
# Out:
#   adding: kaggle/working/runs/detect/train/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/results.png (deflated 9%)
#   adding: kaggle/working/runs/detect/train/confusion_matrix_normalized.png (deflated 17%)
#   adding: kaggle/working/runs/detect/train/confusion_matrix.png (deflated 20%)
#   adding: kaggle/working/runs/detect/train/train_batch7762.jpg (deflated 4%)
#   adding: kaggle/working/runs/detect/train/val_batch1_labels.jpg (deflated 7%)
#   adding: kaggle/working/runs/detect/train/val_batch0_labels.jpg (deflated 7%)
#   adding: kaggle/working/runs/detect/train/args.yaml (deflated 52%)
#   adding: kaggle/working/runs/detect/train/val_batch2_labels.jpg (deflated 8%)
#   adding: kaggle/working/runs/detect/train/labels_correlogram.jpg (deflated 34%)
#   adding: kaggle/working/runs/detect/train/train_batch1.jpg (deflated 2%)
#   adding: kaggle/working/runs/detect/train/val_batch2_pred.jpg (deflated 8%)
# ...

# %%
from IPython.display import FileLink
FileLink('drowsy-v8s-final.zip')
# Out:
# /kaggle/working/drowsy-v8s-final.zip
